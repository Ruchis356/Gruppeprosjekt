# %%
print("Utviklingsmiljøet er klart!")
# Out:
# Utviklingsmiljøet er klart!

# %%
import requests

url = "https://api.met.no/weatherapi/locationforecast/2.0/compact?lat=60.10&lon=9.58"
headers = {
    'User-Agent': 'Miljødataanalyseapplikasjon/1.0 (kontakt@epost.com)'
}

response = requests.get(url, headers=headers)
if response.status_code == 200:
    data = response.json()
    print(data)
else:
    print("Feil ved henting av data:", response.status_code)
# Out:
# {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [9.58, 60.1, 496]}, 'properties': {'meta': {'updated_at': '2025-02-12T12:27:52Z', 'units': {'air_pressure_at_sea_level': 'hPa', 'air_temperature': 'celsius', 'cloud_area_fraction': '%', 'precipitation_amount': 'mm', 'relative_humidity': '%', 'wind_from_direction': 'degrees', 'wind_speed': 'm/s'}}, 'timeseries': [{'time': '2025-02-12T12:00:00Z', 'data': {'instant': {'details': {'air_pressure_at_sea_level': 1032.5, 'air_temperature': -4.3, 'cloud_area_fraction': 2.3, 'relative_humidity': 70.8, 'wind_from_direction': 297.8, 'wind_speed': 0.6}}, 'next_12_hours': {'summary': {'symbol_code': 'fair_day'}, 'details': {}}, 'next_1_hours': {'summary': {'symbol_code': 'clearsky_day'}, 'details': {'precipitation_amount': 0.0}}, 'next_6_hours': {'summary': {'symbol_code': 'clearsky_day'}, 'details': {'precipitation_amount': 0.0}}}}, {'time': '2025-02-12T13:00:00Z', 'data': {'instant': {'details': {'air_pressure_at_sea_level': 1031.7, 'air_temperature': -3.5, 'cloud_area_fraction': 1.7, 'relative_humidity': 69.1, 'wind_from_direction': 271.7, 'wind_speed': 0.6}}, 'next_12_hours': {'summary': {'symbol_code': 'fair_day'}, 'details': {}}, 'next_1_hours': {'summary': {'symbol_code': 'clearsky_day'}, 'details': {'precipitation_amount': 0.0}}, 'next_6_hours': {'summary': {'symbol_code': 'clearsky_day'}, 'details': {'precipitation_amount': 0.0}}}}, {'time': '2025-02-12T14:00:00Z', 'data': {'instant': {'details': {'air_pressure_at_sea_level': 1031.4, 'air_temperature': -3.6, 'cloud_area_fraction': 1.1, 'relative_humidity': 73.2, 'wind_from_direction': 278.3, 'wind_speed': 0.4}}, 'next_12_hours': {'summary': {'symbol_code': 'partlycloudy_night'}, 'details': {}}, 'next_1_hours': {'summary': {'symbol_code': 'clearsky_day'}, 'details': {'precipitation_amount': 0.0}}, 'next_6_hours': {'summary': {'symbol_code': 'clearsky_night'}, 'details': {'precipitation_amount': 0.0}}}}, {'time': '2025-02-12T15:00:00Z', 'data': {'instant': {'details': {'air_pressure_at_sea_level': 1031.3, 'air_temperature': -4.5, 'cloud_area_fraction': 0.6, 'relative_humidity': 83.4, 'wind_from_direction': 69.8, 'wind_speed': 0.7}}, 'next_12_hours': {'summary': {'symbol_code': 'partlycloudy_day'}, 'details': {}}, 'next_1_hours': {'summary': {'symbol_code': 'clearsky_day'}, 'details': {'precipitation_amount': 0.0}}, 'next_6_hours': {'summary': {'symbol_code': 'clearsky_night'}, 'details': {'precipitation_amount': 0.0}}}}, {'time': '2025-02-12T16:00:00Z', 'data': {'instant': {'details': {'air_pressure_at_sea_level': 1031.0, 'air_temperature': -6.3, 'cloud_area_fraction': 0.0, 'relative_humidity': 82.7, 'wind_from_direction': 63.4, 'wind_speed': 1.4}}, 'next_12_hours': {'summary': {'symbol_code': 'partlycloudy_day'}, 'details': {}}, 'next_1_hours': {'summary': {'symbol_code': 'clearsky_night'}, 'details': {'precipitation_amount': 0.0}}, 'next_6_hours': {'summary': {'symbol_code': 'fair_night'}, 'details': {'precipitation_amount': 0.0}}}}, {'time': '2025-02-12T17:00:00Z', 'data': {'instant': {'details': {'air_pressure_at_sea_level': 1030.9, 'air_temperature': -8.3, 'cloud_area_fraction': 0.0, 'relative_humidity': 85.6, 'wind_from_direction': 50.9, 'wind_speed': 1.5}}, 'next_12_hours': {'summary': {'symbol_code': 'partlycloudy_day'}, 'details': {}}, 'next_1_hours': {'summary': {'symbol_code': 'clearsky_night'}, 'details': {'precipitation_amount': 0.0}}, 'next_6_hours': {'summary': {'symbol_code': 'fair_night'}, 'details': {'precipitation_amount': 0.0}}}}, {'time': '2025-02-12T18:00:00Z', 'data': {'instant': {'details': {'air_pressure_at_sea_level': 1030.9, 'air_temperature': -9.5, 'cloud_area_fraction': 0.0, 'relative_humidity': 86.7, 'wind_from_direction': 44.9, 'wind_speed': 1.4}}, 'next_12_hours': {'summary': {'symbol_code': 'partlycloudy_day'}, 'details': {}}, 'next_1_hours': {'summary': {'symbol_code': 'clearsky_night'}, 'details': {'precipitation_amount': 0.0}}, 'next_6_hours': {'summary': {'symbol_code': 'partlycloudy ...
