# %%
print("Utviklingsmiljøet er klart!")
# Out:
# Utviklingsmiljøet er klart!

# %%
import requests
url = "https://api.met.no/weatherapi/locationforecast/2.0/compact?lat=63.415773&lon=10.406423"
headers = {
    'User-Agent': 'Miljødataanalyseapplikasjon/1.0 (kontakt@epost.com)'
}

response = requests.get(url, headers=headers)
if response.status_code == 200:
    data = response.json()
    print(data)
else:
    print("Feil ved henting av data:", response.status_code)
# Out:
# {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [10.4064, 63.4158, 42]}, 'properties': {'meta': {'updated_at': '2025-02-12T13:27:29Z', 'units': {'air_pressure_at_sea_level': 'hPa', 'air_temperature': 'celsius', 'cloud_area_fraction': '%', 'precipitation_amount': 'mm', 'relative_humidity': '%', 'wind_from_direction': 'degrees', 'wind_speed': 'm/s'}}, 'timeseries': [{'time': '2025-02-12T13:00:00Z', 'data': {'instant': {'details': {'air_pressure_at_sea_level': 1033.4, 'air_temperature': 1.1, 'cloud_area_fraction': 77.9, 'relative_humidity': 73.7, 'wind_from_direction': 198.5, 'wind_speed': 1.2}}, 'next_12_hours': {'summary': {'symbol_code': 'partlycloudy_day'}, 'details': {}}, 'next_1_hours': {'summary': {'symbol_code': 'partlycloudy_day'}, 'details': {'precipitation_amount': 0.0}}, 'next_6_hours': {'summary': {'symbol_code': 'cloudy'}, 'details': {'precipitation_amount': 0.0}}}}, {'time': '2025-02-12T14:00:00Z', 'data': {'instant': {'details': {'air_pressure_at_sea_level': 1033.4, 'air_temperature': 1.1, 'cloud_area_fraction': 100.0, 'relative_humidity': 75.5, 'wind_from_direction': 45.8, 'wind_speed': 0.9}}, 'next_12_hours': {'summary': {'symbol_code': 'partlycloudy_night'}, 'details': {}}, 'next_1_hours': {'summary': {'symbol_code': 'cloudy'}, 'details': {'precipitation_amount': 0.0}}, 'next_6_hours': {'summary': {'symbol_code': 'partlycloudy_night'}, 'details': {'precipitation_amount': 0.0}}}}, {'time': '2025-02-12T15:00:00Z', 'data': {'instant': {'details': {'air_pressure_at_sea_level': 1033.4, 'air_temperature': 0.9, 'cloud_area_fraction': 100.0, 'relative_humidity': 82.3, 'wind_from_direction': 39.4, 'wind_speed': 1.4}}, 'next_12_hours': {'summary': {'symbol_code': 'partlycloudy_night'}, 'details': {}}, 'next_1_hours': {'summary': {'symbol_code': 'cloudy'}, 'details': {'precipitation_amount': 0.0}}, 'next_6_hours': {'summary': {'symbol_code': 'partlycloudy_night'}, 'details': {'precipitation_amount': 0.0}}}}, {'time': '2025-02-12T16:00:00Z', 'data': {'instant': {'details': {'air_pressure_at_sea_level': 1033.2, 'air_temperature': 0.6, 'cloud_area_fraction': 100.0, 'relative_humidity': 89.1, 'wind_from_direction': 49.9, 'wind_speed': 0.8}}, 'next_12_hours': {'summary': {'symbol_code': 'partlycloudy_night'}, 'details': {}}, 'next_1_hours': {'summary': {'symbol_code': 'cloudy'}, 'details': {'precipitation_amount': 0.0}}, 'next_6_hours': {'summary': {'symbol_code': 'partlycloudy_night'}, 'details': {'precipitation_amount': 0.0}}}}, {'time': '2025-02-12T17:00:00Z', 'data': {'instant': {'details': {'air_pressure_at_sea_level': 1032.9, 'air_temperature': 0.3, 'cloud_area_fraction': 93.5, 'relative_humidity': 91.7, 'wind_from_direction': 36.6, 'wind_speed': 1.3}}, 'next_12_hours': {'summary': {'symbol_code': 'fair_night'}, 'details': {}}, 'next_1_hours': {'summary': {'symbol_code': 'cloudy'}, 'details': {'precipitation_amount': 0.0}}, 'next_6_hours': {'summary': {'symbol_code': 'fair_night'}, 'details': {'precipitation_amount': 0.0}}}}, {'time': '2025-02-12T18:00:00Z', 'data': {'instant': {'details': {'air_pressure_at_sea_level': 1032.8, 'air_temperature': -0.2, 'cloud_area_fraction': 79.2, 'relative_humidity': 93.3, 'wind_from_direction': 36.4, 'wind_speed': 1.9}}, 'next_12_hours': {'summary': {'symbol_code': 'fair_night'}, 'details': {}}, 'next_1_hours': {'summary': {'symbol_code': 'partlycloudy_night'}, 'details': {'precipitation_amount': 0.0}}, 'next_6_hours': {'summary': {'symbol_code': 'fair_night'}, 'details': {'precipitation_amount': 0.0}}}}, {'time': '2025-02-12T19:00:00Z', 'data': {'instant': {'details': {'air_pressure_at_sea_level': 1032.9, 'air_temperature': -1.0, 'cloud_area_fraction': 47.8, 'relative_humidity': 94.0, 'wind_from_direction': 36.2, 'wind_speed': 1.9}}, 'next_12_hours': {'summary': {'symbol_code': 'fair_night'}, 'details': {}}, 'next_1_hours': {'summary': {'symbol_code': 'partlycloudy_night'}, 'details': {'precipitation_amount': 0.0}}, 'next_6_hours': {'summary': {'symbol_code': 'fair_nig ...
